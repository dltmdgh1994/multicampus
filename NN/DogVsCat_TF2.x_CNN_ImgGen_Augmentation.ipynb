# %% [markdown]
# # 이미지를 ImageDataGenerator로 불러오기

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = 'C:/Users/s_csmscox/jupyterSave/dvc/train_small'
validation_dir = 'C:/Users/s_csmscox/jupyterSave/dvc/valid_small'

batch_size = 20

train_datagen = ImageDataGenerator(rescale=1/255,
                                   rotation_range=20,  # 지정된 각도 범위내에서 임의로 원본 이미지를 회전
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.1,    #  1-수치 혹은 1+수치만큼 확대 및 축소
                                   horizontal_flip=True,
                                   vertical_flip=True)

validation_datagen = ImageDataGenerator(rescale=1/255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    classes=['0', '1'],
    target_size=(128,128),                      
    batch_size=batch_size,     
    class_mode='categorical'                    
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    classes=['0', '1'],
    target_size=(128,128),                       
    batch_size=batch_size,    
    class_mode='categorical'                    
)
# Out:
# Found 3000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# # 모델 학습

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

np.random.seed(42)

#모델 구축

earlystopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), padding='same',
                 activation='relu',
                 input_shape=(128, 128, 3)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(2, activation='softmax'))
model.summary()
model.compile(optimizer=Adam(learning_rate=1e-4), loss='categorical_crossentropy',
                metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               16777728
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 17,196,578
# Trainable params: 17,196,578
# Non-trainable params: 0
# _________________________________________________________________

# %%
#모델 학습
early_stopping = EarlyStopping(patience = 5) # 조기종료 콜백함수 정의

# 데이터 개수 / batch_size
steps_per_epoch = 3000 / batch_size
val_steps = 1000 / batch_size

history = model.fit(train_generator,
                    steps_per_epoch=steps_per_epoch,
                    epochs=100,
                    validation_data=validation_generator,
                    validation_steps=val_steps,
                    callbacks=[early_stopping],
                    verbose=1
                    )
# Out:
# Epoch 1/100
#   1/150 [..............................] - ETA: 0s - loss: 0.6943 - accuracy: 0.4500WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0060s vs `on_train_batch_end` time: 0.0110s). Check your callbacks.
# 150/150 [==============================] - 15s 97ms/step - loss: 0.6922 - accuracy: 0.5210 - val_loss: 0.6658 - val_accuracy: 0.6160
# Epoch 2/100
# 150/150 [==============================] - 15s 97ms/step - loss: 0.6580 - accuracy: 0.5917 - val_loss: 0.6334 - val_accuracy: 0.6420
# Epoch 3/100
# 150/150 [==============================] - 14s 95ms/step - loss: 0.6076 - accuracy: 0.6607 - val_loss: 0.6524 - val_accuracy: 0.6510
# Epoch 4/100
# 150/150 [==============================] - 14s 95ms/step - loss: 0.5919 - accuracy: 0.6773 - val_loss: 0.5863 - val_accuracy: 0.7070
# Epoch 5/100
# 150/150 [==============================] - 14s 96ms/step - loss: 0.5738 - accuracy: 0.6940 - val_loss: 0.5906 - val_accuracy: 0.6920
# Epoch 6/100
# 150/150 [==============================] - 14s 95ms/step - loss: 0.5567 - accuracy: 0.7030 - val_loss: 0.5891 - val_accuracy: 0.7060
# Epoch 7/100
# 150/150 [==============================] - 15s 97ms/step - loss: 0.5544 - accuracy: 0.7067 - val_loss: 0.5435 - val_accuracy: 0.7480
# Epoch 8/100
# 150/150 [==============================] - 15s 97ms/step - loss: 0.5411 - accuracy: 0.7227 - val_loss: 0.5364 - val_accuracy: 0.7420
# Epoch 9/100
# 150/150 [==============================] - 15s 97ms/step - loss: 0.5497 - accuracy: 0.7070 - val_loss: 0.5306 - val_accuracy: 0.7560
# Epoch 10/100
# 150/150 [==============================] - 14s 95ms/step - loss: 0.5219 - accuracy: 0.7367 - val_loss: 0.5467 - val_accuracy: 0.7260
# Epoch 11/100
# 150/150 [==============================] - 15s 98ms/step - loss: 0.5287 - accuracy: 0.7237 - val_loss: 0.5183 - val_accuracy: 0.7610
# Epoch 12/100
# 150/150 [==============================] - 14s 96ms/step - loss: 0.5191 - accuracy: 0.7443 - val_loss: 0.5308 - val_accuracy: 0.7510
# Epoch 13/100
# 150/150 [==============================] - 14s 96ms/step - loss: 0.5059 - accuracy: 0.7490 - val_loss: 0.5381 - val_accuracy: 0.7410
# Epoch 14/100
# 150/150 [==============================] - 14s 95ms/step - loss: 0.4902 - accuracy: 0.7497 - val_loss: 0.5356 - val_accuracy: 0.7320
# Epoch 15/100
# 150/150 [==============================] - 14s 95ms/step - loss: 0.4946 - accuracy: 0.7613 - val_loss: 0.5024 - val_accuracy: 0.7550
# Epoch 16/100
# 150/150 [==============================] - 14s 97ms/step - loss: 0.4866 - accuracy: 0.7583 - val_loss: 0.4840 - val_accuracy: 0.7760
# Epoch 17/100
# 150/150 [==============================] - 14s 95ms/step - loss: 0.4898 - accuracy: 0.7590 - val_loss: 0.4828 - val_accuracy: 0.7760
# Epoch 18/100
# 150/150 [==============================] - 14s 95ms/step - loss: 0.4796 - accuracy: 0.7660 - val_loss: 0.4716 - val_accuracy: 0.7780
# Epoch 19/100
# 150/150 [==============================] - 14s 95ms/step - loss: 0.4661 - accuracy: 0.7740 - val_loss: 0.5348 - val_accuracy: 0.7250
# Epoch 20/100
# 150/150 [==============================] - 15s 97ms/step - loss: 0.4652 - accuracy: 0.7760 - val_loss: 0.4652 - val_accuracy: 0.7860
# Epoch 21/100
# 150/150 [==============================] - 15s 98ms/step - loss: 0.4626 - accuracy: 0.7837 - val_loss: 0.5124 - val_accuracy: 0.7710
# Epoch 22/100
# 150/150 [==============================] - 14s 96ms/step - loss: 0.4475 - accuracy: 0.7930 - val_loss: 0.4531 - val_accuracy: 0.7860
# Epoch 23/100
# 150/150 [==============================] - 14s 95ms/step - loss: 0.4494 - accuracy: 0.7883 - val_loss: 0.4684 - val_accuracy: 0.7820
# Epoch 24/100
# 150/150 [==============================] - 14s 95ms/step - loss: 0.4419 - accuracy: 0.7847 - val_loss: 0.4815 - val_accuracy: 0.7870
# Epoch 25/100
# 150/150 [==============================] - 14s 95ms/step - loss: 0.4387 - accuracy: 0.7953 - val_loss: 0.4593 - val_accuracy: 0.7870
# Epoch 26/100
# 150/150 [==============================] - 14s 95ms/step - loss: 0.4366 - accuracy: 0.8007 - val_loss: 0.5011 - val_accuracy: 0.7720
# Epoch 27/100
# 150/150 [==============================] - 14s 95ms/step - loss: 0.4240 - accuracy: 0.8077 - val_loss: 0.4517 - val_accuracy: 0.7910
# Epoch 28/100
# 150/150 [==============================] - 14s 96ms/step - loss: 0.4252 - accuracy: 0.8057 - val_loss: 0.4415 - val_accuracy: 0.8000
# Epoch 29/100
# 150/150 [==============================] - 14s 96ms/step - loss: 0.4187 - accuracy: 0.8060 - val_loss: 0.4634 - val_accuracy: 0.7770
# Epoch 30/100
# 150/150 [==============================] - 15s 97ms/step - loss: 0.4215 - accuracy: 0.8027 - val_loss: 0.4408 - val_accuracy: 0.8030
# Epoch 31/100
# 150/150 [==============================] - 14s 95ms/step - loss: 0.4154 - accuracy: 0.8107 - val_loss: 0.4230 - val_accuracy: 0.8030
# Epoch 32/100
# 150/150 [==============================] - 14s 95ms/step - loss: 0.4044 - accuracy: 0.8120 - val_loss: 0.4676 - val_accuracy: 0.7810
# Epoch 33/100
# 150/150 [==============================] - 14s 96ms/step - loss: 0.4100 - accuracy: 0.8087 - val_loss: 0.4477 - val_accuracy: 0.7850
# Epoch 34/100
# 150/150 [==============================] - 14s 96ms/step - loss: 0.3958 - accuracy: 0.8200 - val_loss: 0.4225 - val_accuracy: 0.7950
# Epoch 35/100
# 150/150 [==============================] - 14s 95ms/step - loss: 0.3954 - accuracy: 0.8220 - val_loss: 0.4389 - val_accuracy: 0.8050
# Epoch 36/100
# 150/150 [==============================] - 14s 95ms/step - loss: 0.4088 - accuracy: 0.8113 - val_loss: 0.4238 - val_accuracy: 0.8010
# Epoch 37/100
# 150/150 [==============================] - 14s 96ms/step - loss: 0.3786 - accuracy: 0.8280 - val_loss: 0.4604 - val_accuracy: 0.7740
# Epoch 38/100
# 150/150 [==============================] - 14s 96ms/step - loss: 0.3862 - accuracy: 0.8247 - val_loss: 0.4453 - val_accuracy: 0.7950
# Epoch 39/100
# 150/150 [==============================] - 14s 95ms/step - loss: 0.3893 - accuracy: 0.8177 - val_loss: 0.4466 - val_accuracy: 0.7840

# %%
# 학습 곡선을 나타내는 함수
def plot_loss_curve(history):
    plt.figure(figsize=(15, 10))

    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show()   
    
    print("train loss=", history.history['loss'][-1])
    print("validation loss=", history.history['val_loss'][-1])
    
def plot_acc_curve(history):
    plt.figure(figsize=(15, 10))

    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show()   
    
    print("train accuracy=", history.history['accuracy'][-1])
    print("validation accuracy=", history.history['val_accuracy'][-1])
    
plot_loss_curve(history)
plot_acc_curve(history)
# Out:
# train loss= 0.38930338621139526
# validation loss= 0.4465521275997162
# train accuracy= 0.8176666498184204
# validation accuracy= 0.7839999794960022

# %%
import pathlib
import os,glob
import numpy as np
from PIL import Image

directory = 'C:/Users/s_csmscox/jupyterSave/dvc/test'
categories = ["0","1"] # dog = 1, cat = 0
nb_classes = len(categories)

w = 128
h = 128

X = []
y = []

for idx, obj in enumerate(categories):

    image_dir = directory + "/" + obj
    files = glob.glob(image_dir+"/*.jpg")
    print(obj, " 파일 길이 : ", len(files))
    
    for i, f in enumerate(files):
        img = Image.open(f)
        
        # 사이즈 조절
        img = img.resize((w, h))
        
        img = np.asarray(img)
        img = img.reshape(w,h,3)

        X.append(img)
        y.append(idx)

        if i % 10000 == 0:
            print(obj, " : ", f)
# Out:
# 0  파일 길이 :  2500
# 0  :  C:/Users/s_csmscox/jupyterSave/dvc/test/0\cat.7500.jpg
# 1  파일 길이 :  2500
# 1  :  C:/Users/s_csmscox/jupyterSave/dvc/test/1\dog.7500.jpg

# %%
from tensorflow.keras.utils import to_categorical

X_test = np.array(X)
X_test = X_test/255

y_test = np.array(y)
y_test = to_categorical(y_test)

# %%
# 모델 평가
print("-- Evaluate --")
scores = model.evaluate(X_test, y_test)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))
# Out:
# -- Evaluate --
# 157/157 [==============================] - 1s 8ms/step - loss: 0.4466 - accuracy: 0.7962
# accuracy: 79.62%
