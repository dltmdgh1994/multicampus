# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = 'C:/Users/s_csmscox/jupyterSave/dvc/train'
validation_dir = 'C:/Users/s_csmscox/jupyterSave/dvc/valid'

batch_size = 20

train_datagen = ImageDataGenerator(rescale=1/255,
                                   rotation_range=20,  # 지정된 각도 범위내에서 임의로 원본 이미지를 회전
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.1,    #  1-수치 혹은 1+수치만큼 확대 및 축소
                                   horizontal_flip=True,
                                   vertical_flip=True)

validation_datagen = ImageDataGenerator(rescale=1/255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    classes=['0', '1'],
    target_size=(224,224),                      
    batch_size=batch_size,     
    class_mode='categorical'                    
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    classes=['0', '1'],
    target_size=(224,224),                       
    batch_size=batch_size,    
    class_mode='categorical'                    
)
# Out:
# Found 15000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.

# %% [markdown]
# # Feature Extraction

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from keras.applications import VGG16

np.random.seed(42)

# 모델 구축

# vgg16 모델 불러오기
pre_trained_vgg = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
pre_trained_vgg.trainable = False
pre_trained_vgg.summary()

# vgg16 모델에 덧붙이기
model = Sequential()
model.add(pre_trained_vgg)
model.add(Flatten())
model.add(Dense(4096, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(2048, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1024, activation='relu', kernel_initializer='he_normal'))

model.add(Dense(2, activation='softmax'))

model.summary()

model.compile(optimizer=Adam(learning_rate=1e-7), loss='categorical_crossentropy',
                metrics=['accuracy'])
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              102764544
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              8390656
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 127,970,114
# Trainable params: 113,255,426
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
#모델 학습
early_stopping = EarlyStopping(patience = 5) # 조기종료 콜백함수 정의

# 데이터 개수 / batch_size
steps_per_epoch = 15000 / batch_size
val_steps = 5000 / batch_size

history = model.fit(train_generator,
                    steps_per_epoch=steps_per_epoch,
                    epochs=100,
                    validation_data=validation_generator,
                    validation_steps=val_steps,
                    callbacks=[early_stopping],
                    verbose=1
                    )
# Out:
# Epoch 1/100
# 750/750 [==============================] - 148s 197ms/step - loss: 0.6707 - accuracy: 0.5837 - val_loss: 0.6029 - val_accuracy: 0.7026
# Epoch 2/100
# 750/750 [==============================] - 149s 198ms/step - loss: 0.5908 - accuracy: 0.7112 - val_loss: 0.5216 - val_accuracy: 0.7834
# Epoch 3/100
# 750/750 [==============================] - 147s 196ms/step - loss: 0.5426 - accuracy: 0.7538 - val_loss: 0.4673 - val_accuracy: 0.8166
# Epoch 4/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.5041 - accuracy: 0.7808 - val_loss: 0.4277 - val_accuracy: 0.8362
# Epoch 5/100
# 750/750 [==============================] - 146s 195ms/step - loss: 0.4741 - accuracy: 0.7968 - val_loss: 0.3982 - val_accuracy: 0.8484
# Epoch 6/100
# 750/750 [==============================] - 146s 195ms/step - loss: 0.4519 - accuracy: 0.8076 - val_loss: 0.3756 - val_accuracy: 0.8584
# Epoch 7/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.4354 - accuracy: 0.8198 - val_loss: 0.3568 - val_accuracy: 0.8666
# Epoch 8/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.4174 - accuracy: 0.8249 - val_loss: 0.3405 - val_accuracy: 0.8738
# Epoch 9/100
# 750/750 [==============================] - 146s 195ms/step - loss: 0.4043 - accuracy: 0.8318 - val_loss: 0.3308 - val_accuracy: 0.8748
# Epoch 10/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.3962 - accuracy: 0.8358 - val_loss: 0.3164 - val_accuracy: 0.8806
# Epoch 11/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.3845 - accuracy: 0.8405 - val_loss: 0.3069 - val_accuracy: 0.8840
# Epoch 12/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.3776 - accuracy: 0.8390 - val_loss: 0.2991 - val_accuracy: 0.8848
# Epoch 13/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.3666 - accuracy: 0.8463 - val_loss: 0.2909 - val_accuracy: 0.8890
# Epoch 14/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.3612 - accuracy: 0.8463 - val_loss: 0.2852 - val_accuracy: 0.8900
# Epoch 15/100
# 750/750 [==============================] - 146s 195ms/step - loss: 0.3549 - accuracy: 0.8487 - val_loss: 0.2787 - val_accuracy: 0.8936
# Epoch 16/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.3506 - accuracy: 0.8529 - val_loss: 0.2757 - val_accuracy: 0.8946
# Epoch 17/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.3426 - accuracy: 0.8569 - val_loss: 0.2717 - val_accuracy: 0.8966
# Epoch 18/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.3418 - accuracy: 0.8535 - val_loss: 0.2660 - val_accuracy: 0.8994
# Epoch 19/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.3353 - accuracy: 0.8603 - val_loss: 0.2629 - val_accuracy: 0.9004
# Epoch 20/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.3310 - accuracy: 0.8617 - val_loss: 0.2583 - val_accuracy: 0.9010
# Epoch 21/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.3257 - accuracy: 0.8614 - val_loss: 0.2580 - val_accuracy: 0.9010
# Epoch 22/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.3222 - accuracy: 0.8648 - val_loss: 0.2520 - val_accuracy: 0.9038
# Epoch 23/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.3200 - accuracy: 0.8680 - val_loss: 0.2490 - val_accuracy: 0.9036
# Epoch 24/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.3184 - accuracy: 0.8657 - val_loss: 0.2481 - val_accuracy: 0.9052
# Epoch 25/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.3151 - accuracy: 0.8655 - val_loss: 0.2461 - val_accuracy: 0.9054
# Epoch 26/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.3123 - accuracy: 0.8670 - val_loss: 0.2418 - val_accuracy: 0.9058
# Epoch 27/100
# 750/750 [==============================] - 146s 195ms/step - loss: 0.3077 - accuracy: 0.8696 - val_loss: 0.2410 - val_accuracy: 0.9072
# Epoch 28/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.3071 - accuracy: 0.8680 - val_loss: 0.2406 - val_accuracy: 0.9074
# Epoch 29/100
# 750/750 [==============================] - 145s 194ms/step - loss: 0.3022 - accuracy: 0.8740 - val_loss: 0.2353 - val_accuracy: 0.9092
# Epoch 30/100
# 750/750 [==============================] - 145s 194ms/step - loss: 0.3033 - accuracy: 0.8729 - val_loss: 0.2359 - val_accuracy: 0.9096
# Epoch 31/100
# 750/750 [==============================] - 145s 194ms/step - loss: 0.2988 - accuracy: 0.8739 - val_loss: 0.2319 - val_accuracy: 0.9104
# Epoch 32/100
# 750/750 [==============================] - 145s 194ms/step - loss: 0.2956 - accuracy: 0.8773 - val_loss: 0.2317 - val_accuracy: 0.9100
# Epoch 33/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2922 - accuracy: 0.8779 - val_loss: 0.2305 - val_accuracy: 0.9100
# Epoch 34/100
# 750/750 [==============================] - 149s 199ms/step - loss: 0.2951 - accuracy: 0.8726 - val_loss: 0.2304 - val_accuracy: 0.9100
# Epoch 35/100
# 750/750 [==============================] - 152s 203ms/step - loss: 0.2915 - accuracy: 0.8773 - val_loss: 0.2269 - val_accuracy: 0.9120
# Epoch 36/100
# 750/750 [==============================] - 153s 204ms/step - loss: 0.2905 - accuracy: 0.8799 - val_loss: 0.2299 - val_accuracy: 0.9100
# Epoch 37/100
# 750/750 [==============================] - 151s 202ms/step - loss: 0.2864 - accuracy: 0.8797 - val_loss: 0.2274 - val_accuracy: 0.9094
# Epoch 38/100
# 750/750 [==============================] - 154s 205ms/step - loss: 0.2846 - accuracy: 0.8787 - val_loss: 0.2255 - val_accuracy: 0.9110
# Epoch 39/100
# 750/750 [==============================] - 155s 206ms/step - loss: 0.2840 - accuracy: 0.8805 - val_loss: 0.2221 - val_accuracy: 0.9136
# Epoch 40/100
# 750/750 [==============================] - 152s 203ms/step - loss: 0.2864 - accuracy: 0.8811 - val_loss: 0.2216 - val_accuracy: 0.9132
# Epoch 41/100
# 750/750 [==============================] - 157s 209ms/step - loss: 0.2830 - accuracy: 0.8811 - val_loss: 0.2202 - val_accuracy: 0.9132
# Epoch 42/100
# 750/750 [==============================] - 157s 209ms/step - loss: 0.2822 - accuracy: 0.8801 - val_loss: 0.2201 - val_accuracy: 0.9146
# Epoch 43/100
# 750/750 [==============================] - 156s 208ms/step - loss: 0.2758 - accuracy: 0.8843 - val_loss: 0.2186 - val_accuracy: 0.9152
# Epoch 44/100
# 750/750 [==============================] - 154s 205ms/step - loss: 0.2796 - accuracy: 0.8829 - val_loss: 0.2213 - val_accuracy: 0.9126
# Epoch 45/100
# 750/750 [==============================] - 152s 202ms/step - loss: 0.2780 - accuracy: 0.8809 - val_loss: 0.2168 - val_accuracy: 0.9156
# Epoch 46/100
# 750/750 [==============================] - 152s 203ms/step - loss: 0.2728 - accuracy: 0.8836 - val_loss: 0.2160 - val_accuracy: 0.9160
# Epoch 47/100
# 750/750 [==============================] - 152s 203ms/step - loss: 0.2715 - accuracy: 0.8880 - val_loss: 0.2158 - val_accuracy: 0.9158
# Epoch 48/100
# 750/750 [==============================] - 146s 195ms/step - loss: 0.2722 - accuracy: 0.8840 - val_loss: 0.2180 - val_accuracy: 0.9144
# Epoch 49/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2706 - accuracy: 0.8842 - val_loss: 0.2147 - val_accuracy: 0.9164
# Epoch 50/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2694 - accuracy: 0.8860 - val_loss: 0.2127 - val_accuracy: 0.9166
# Epoch 51/100
# 750/750 [==============================] - 146s 195ms/step - loss: 0.2677 - accuracy: 0.8864 - val_loss: 0.2141 - val_accuracy: 0.9168
# Epoch 52/100
# 750/750 [==============================] - 146s 195ms/step - loss: 0.2697 - accuracy: 0.8833 - val_loss: 0.2108 - val_accuracy: 0.9146
# Epoch 53/100
# 750/750 [==============================] - 146s 195ms/step - loss: 0.2717 - accuracy: 0.8836 - val_loss: 0.2149 - val_accuracy: 0.9158
# Epoch 54/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2673 - accuracy: 0.8869 - val_loss: 0.2103 - val_accuracy: 0.9174
# Epoch 55/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2623 - accuracy: 0.8888 - val_loss: 0.2097 - val_accuracy: 0.9178
# Epoch 56/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2673 - accuracy: 0.8866 - val_loss: 0.2097 - val_accuracy: 0.9172
# Epoch 57/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2625 - accuracy: 0.8892 - val_loss: 0.2116 - val_accuracy: 0.9174
# Epoch 58/100
# 750/750 [==============================] - 146s 195ms/step - loss: 0.2645 - accuracy: 0.8887 - val_loss: 0.2099 - val_accuracy: 0.9180
# Epoch 59/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2626 - accuracy: 0.8885 - val_loss: 0.2076 - val_accuracy: 0.9180
# Epoch 60/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2609 - accuracy: 0.8907 - val_loss: 0.2086 - val_accuracy: 0.9178
# Epoch 61/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2578 - accuracy: 0.8926 - val_loss: 0.2072 - val_accuracy: 0.9170
# Epoch 62/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2575 - accuracy: 0.8912 - val_loss: 0.2056 - val_accuracy: 0.9166
# Epoch 63/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2604 - accuracy: 0.8879 - val_loss: 0.2129 - val_accuracy: 0.9172
# Epoch 64/100
# 750/750 [==============================] - 145s 194ms/step - loss: 0.2576 - accuracy: 0.8942 - val_loss: 0.2074 - val_accuracy: 0.9186
# Epoch 65/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2542 - accuracy: 0.8953 - val_loss: 0.2061 - val_accuracy: 0.9188
# Epoch 66/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2565 - accuracy: 0.8919 - val_loss: 0.2043 - val_accuracy: 0.9176
# Epoch 67/100
# 750/750 [==============================] - 145s 194ms/step - loss: 0.2531 - accuracy: 0.8940 - val_loss: 0.2039 - val_accuracy: 0.9192
# Epoch 68/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2531 - accuracy: 0.8959 - val_loss: 0.2068 - val_accuracy: 0.9200
# Epoch 69/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2555 - accuracy: 0.8917 - val_loss: 0.2056 - val_accuracy: 0.9202
# Epoch 70/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2529 - accuracy: 0.8933 - val_loss: 0.2024 - val_accuracy: 0.9180
# Epoch 71/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2551 - accuracy: 0.8920 - val_loss: 0.2051 - val_accuracy: 0.9202
# Epoch 72/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2498 - accuracy: 0.8977 - val_loss: 0.2015 - val_accuracy: 0.9194
# Epoch 73/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2510 - accuracy: 0.8933 - val_loss: 0.2031 - val_accuracy: 0.9196
# Epoch 74/100
# 750/750 [==============================] - 146s 195ms/step - loss: 0.2545 - accuracy: 0.8923 - val_loss: 0.2008 - val_accuracy: 0.9206
# Epoch 75/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2513 - accuracy: 0.8967 - val_loss: 0.2010 - val_accuracy: 0.9210
# Epoch 76/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2500 - accuracy: 0.8938 - val_loss: 0.1997 - val_accuracy: 0.9200
# Epoch 77/100
# 750/750 [==============================] - 146s 195ms/step - loss: 0.2483 - accuracy: 0.8973 - val_loss: 0.1991 - val_accuracy: 0.9200
# Epoch 78/100
# 750/750 [==============================] - 145s 194ms/step - loss: 0.2500 - accuracy: 0.8947 - val_loss: 0.1991 - val_accuracy: 0.9230
# Epoch 79/100
# 750/750 [==============================] - 145s 194ms/step - loss: 0.2476 - accuracy: 0.8935 - val_loss: 0.2027 - val_accuracy: 0.9194
# Epoch 80/100
# 750/750 [==============================] - 146s 195ms/step - loss: 0.2496 - accuracy: 0.8942 - val_loss: 0.1992 - val_accuracy: 0.9222
# Epoch 81/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2428 - accuracy: 0.8968 - val_loss: 0.2004 - val_accuracy: 0.9206
# Epoch 82/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2433 - accuracy: 0.8987 - val_loss: 0.1988 - val_accuracy: 0.9230
# Epoch 83/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2490 - accuracy: 0.8953 - val_loss: 0.2002 - val_accuracy: 0.9212
# Epoch 84/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2462 - accuracy: 0.8971 - val_loss: 0.1984 - val_accuracy: 0.9232
# Epoch 85/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2413 - accuracy: 0.8995 - val_loss: 0.1967 - val_accuracy: 0.9218
# Epoch 86/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2425 - accuracy: 0.8981 - val_loss: 0.1965 - val_accuracy: 0.9214
# Epoch 87/100
# 750/750 [==============================] - 146s 195ms/step - loss: 0.2432 - accuracy: 0.8980 - val_loss: 0.1978 - val_accuracy: 0.9222
# Epoch 88/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2446 - accuracy: 0.8965 - val_loss: 0.1973 - val_accuracy: 0.9214
# Epoch 89/100
# 750/750 [==============================] - 146s 195ms/step - loss: 0.2391 - accuracy: 0.8986 - val_loss: 0.1967 - val_accuracy: 0.9226
# Epoch 90/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2400 - accuracy: 0.8991 - val_loss: 0.2004 - val_accuracy: 0.9222
# Epoch 91/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2394 - accuracy: 0.8991 - val_loss: 0.1950 - val_accuracy: 0.9234
# Epoch 92/100
# 750/750 [==============================] - 147s 196ms/step - loss: 0.2447 - accuracy: 0.8959 - val_loss: 0.1962 - val_accuracy: 0.9232
# Epoch 93/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2395 - accuracy: 0.8963 - val_loss: 0.1948 - val_accuracy: 0.9216
# Epoch 94/100
# 750/750 [==============================] - 145s 194ms/step - loss: 0.2396 - accuracy: 0.8987 - val_loss: 0.1947 - val_accuracy: 0.9218
# Epoch 95/100
# 750/750 [==============================] - 145s 194ms/step - loss: 0.2374 - accuracy: 0.8992 - val_loss: 0.1959 - val_accuracy: 0.9228
# Epoch 96/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2393 - accuracy: 0.9004 - val_loss: 0.1953 - val_accuracy: 0.9228
# Epoch 97/100
# 750/750 [==============================] - 145s 194ms/step - loss: 0.2376 - accuracy: 0.8991 - val_loss: 0.2006 - val_accuracy: 0.9210
# Epoch 98/100
# 750/750 [==============================] - 145s 194ms/step - loss: 0.2338 - accuracy: 0.9038 - val_loss: 0.1979 - val_accuracy: 0.9226
# Epoch 99/100
# 750/750 [==============================] - 146s 194ms/step - loss: 0.2387 - accuracy: 0.9001 - val_loss: 0.1991 - val_accuracy: 0.9206

# %%
# 학습 곡선을 나타내는 함수
def plot_loss_curve(history):
    plt.figure(figsize=(15, 10))

    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show()   
    
    print("train loss=", history.history['loss'][-1])
    print("validation loss=", history.history['val_loss'][-1])
    
def plot_acc_curve(history):
    plt.figure(figsize=(15, 10))

    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show()   
    
    print("train accuracy=", history.history['accuracy'][-1])
    print("validation accuracy=", history.history['val_accuracy'][-1])
    
plot_loss_curve(history)
plot_acc_curve(history)
# Out:
# train loss= 0.23865339159965515
# validation loss= 0.19912777841091156
# train accuracy= 0.9001333117485046
# validation accuracy= 0.9205999970436096

# %%
model.save('C:/Users/s_csmscox/jupyterSave/dvc/dvc_VGG16_ImgGen_224')
# Out:
# WARNING:tensorflow:From C:\Users\s_csmscox\Anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\s_csmscox\Anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: C:/Users/s_csmscox/jupyterSave/dvc/dvc_VGG16_ImgGen_224\assets

# %%
import pathlib
import os,glob
import numpy as np
from PIL import Image

directory = 'C:/Users/s_csmscox/jupyterSave/dvc/test'
categories = ["0","1"] # dog = 1, cat = 0
nb_classes = len(categories)

w = 224
h = 224

X = []
y = []

for idx, obj in enumerate(categories):

    image_dir = directory + "/" + obj
    files = glob.glob(image_dir+"/*.jpg")
    print(obj, " 파일 길이 : ", len(files))
    
    for i, f in enumerate(files):
        img = Image.open(f)
        
        # 사이즈 조절
        img = img.resize((w, h))
        
        img = np.asarray(img)
        img = img.reshape(w,h,3)

        X.append(img)
        y.append(idx)

        if i % 10000 == 0:
            print(obj, " : ", f)
# Out:
# 0  파일 길이 :  2500
# 0  :  C:/Users/s_csmscox/jupyterSave/dvc/test/0\cat.7500.jpg
# 1  파일 길이 :  2500
# 1  :  C:/Users/s_csmscox/jupyterSave/dvc/test/1\dog.7500.jpg

# %%
from tensorflow.keras.utils import to_categorical

X_test = np.array(X)
X_test = X_test/255

y_test = np.array(y)
y_test = to_categorical(y_test)

# %%
# 모델 평가
print("-- Evaluate --")
scores = model.evaluate(X_test, y_test)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))
# Out:
# -- Evaluate --
# 157/157 [==============================] - 10s 65ms/step - loss: 0.1819 - accuracy: 0.9260
# accuracy: 92.60%

# %% [markdown]
# # Fine Tuning

# %%
import numpy as np
from tensorflow.keras.models import load_model

model = load_model('C:/Users/s_csmscox/jupyterSave/dvc/dvc_VGG16_ImgGen_224')

# %%
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from keras.applications import VGG16

pre_trained_vgg = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

pre_trained_vgg.trainable = True

for layer in pre_trained_vgg.layers:
    if layer.name in ['block5_conv1', 'block5_conv2', 'block5_conv3']:
        layer.trainable = True
    else:
        layer.trainable = False

model.compile(optimizer=Adam(learning_rate=1e-7), loss='categorical_crossentropy',
                metrics=['accuracy'])

#모델 학습
early_stopping = EarlyStopping(patience = 5) # 조기종료 콜백함수 정의

batch_size = 20

# 데이터 개수 / batch_size
steps_per_epoch = 15000 / batch_size
val_steps = 5000 / batch_size

history = model.fit(train_generator,
                    steps_per_epoch=steps_per_epoch,
                    epochs=100,
                    validation_data=validation_generator,
                    validation_steps=val_steps,
                    callbacks=[early_stopping],
                    verbose=1
                    )
# Out:
# Epoch 1/100
#   2/750 [..............................] - ETA: 1:04 - loss: 0.2147 - accuracy: 0.9250WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0490s vs `on_train_batch_end` time: 0.1231s). Check your callbacks.
# 750/750 [==============================] - 162s 216ms/step - loss: 0.2283 - accuracy: 0.9015 - val_loss: 0.1737 - val_accuracy: 0.9330
# Epoch 2/100
# 750/750 [==============================] - 148s 198ms/step - loss: 0.2131 - accuracy: 0.9093 - val_loss: 0.1620 - val_accuracy: 0.9350
# Epoch 3/100
# 750/750 [==============================] - 150s 200ms/step - loss: 0.2044 - accuracy: 0.9131 - val_loss: 0.1521 - val_accuracy: 0.9380
# Epoch 4/100
# 750/750 [==============================] - 150s 200ms/step - loss: 0.1973 - accuracy: 0.9176 - val_loss: 0.1472 - val_accuracy: 0.9424
# Epoch 5/100
# 750/750 [==============================] - 150s 200ms/step - loss: 0.1874 - accuracy: 0.9207 - val_loss: 0.1380 - val_accuracy: 0.9462
# Epoch 6/100
# 750/750 [==============================] - 151s 202ms/step - loss: 0.1807 - accuracy: 0.9249 - val_loss: 0.1388 - val_accuracy: 0.9474
# Epoch 7/100
# 750/750 [==============================] - 152s 202ms/step - loss: 0.1750 - accuracy: 0.9293 - val_loss: 0.1312 - val_accuracy: 0.9504
# Epoch 8/100
# 750/750 [==============================] - 150s 200ms/step - loss: 0.1700 - accuracy: 0.9293 - val_loss: 0.1284 - val_accuracy: 0.9520
# Epoch 9/100
# 750/750 [==============================] - 150s 200ms/step - loss: 0.1693 - accuracy: 0.9290 - val_loss: 0.1292 - val_accuracy: 0.9516
# Epoch 10/100
# 750/750 [==============================] - 153s 204ms/step - loss: 0.1619 - accuracy: 0.9339 - val_loss: 0.1208 - val_accuracy: 0.9538
# Epoch 11/100
# 750/750 [==============================] - 148s 197ms/step - loss: 0.1606 - accuracy: 0.9338 - val_loss: 0.1168 - val_accuracy: 0.9548
# Epoch 12/100
# 750/750 [==============================] - 147s 197ms/step - loss: 0.1508 - accuracy: 0.9373 - val_loss: 0.1198 - val_accuracy: 0.9550
# Epoch 13/100
# 750/750 [==============================] - 146s 195ms/step - loss: 0.1541 - accuracy: 0.9363 - val_loss: 0.1121 - val_accuracy: 0.9574
# Epoch 14/100
# 750/750 [==============================] - 149s 199ms/step - loss: 0.1484 - accuracy: 0.9376 - val_loss: 0.1156 - val_accuracy: 0.9568
# Epoch 15/100
# 750/750 [==============================] - 150s 200ms/step - loss: 0.1478 - accuracy: 0.9404 - val_loss: 0.1090 - val_accuracy: 0.9588
# Epoch 16/100
# 750/750 [==============================] - 150s 200ms/step - loss: 0.1441 - accuracy: 0.9405 - val_loss: 0.1085 - val_accuracy: 0.9600
# Epoch 17/100
# 750/750 [==============================] - 151s 201ms/step - loss: 0.1406 - accuracy: 0.9435 - val_loss: 0.1069 - val_accuracy: 0.9596
# Epoch 18/100
# 750/750 [==============================] - 150s 200ms/step - loss: 0.1384 - accuracy: 0.9427 - val_loss: 0.1044 - val_accuracy: 0.9614
# Epoch 19/100
# 750/750 [==============================] - 150s 200ms/step - loss: 0.1362 - accuracy: 0.9458 - val_loss: 0.1043 - val_accuracy: 0.9616
# Epoch 20/100
# 750/750 [==============================] - 150s 200ms/step - loss: 0.1362 - accuracy: 0.9438 - val_loss: 0.1061 - val_accuracy: 0.9616
# Epoch 21/100
# 750/750 [==============================] - 153s 204ms/step - loss: 0.1310 - accuracy: 0.9462 - val_loss: 0.0990 - val_accuracy: 0.9642
# Epoch 22/100
# 750/750 [==============================] - 154s 206ms/step - loss: 0.1278 - accuracy: 0.9470 - val_loss: 0.0964 - val_accuracy: 0.9654
# Epoch 23/100
# 750/750 [==============================] - 153s 204ms/step - loss: 0.1285 - accuracy: 0.9469 - val_loss: 0.0977 - val_accuracy: 0.9656
# Epoch 24/100
# 750/750 [==============================] - 152s 203ms/step - loss: 0.1253 - accuracy: 0.9493 - val_loss: 0.0970 - val_accuracy: 0.9660
# Epoch 25/100
# 750/750 [==============================] - 152s 203ms/step - loss: 0.1217 - accuracy: 0.9514 - val_loss: 0.0950 - val_accuracy: 0.9662
# Epoch 26/100
# 750/750 [==============================] - 151s 201ms/step - loss: 0.1207 - accuracy: 0.9515 - val_loss: 0.0950 - val_accuracy: 0.9668
# Epoch 27/100
# 750/750 [==============================] - 150s 200ms/step - loss: 0.1165 - accuracy: 0.9537 - val_loss: 0.0937 - val_accuracy: 0.9666
# Epoch 28/100
# 750/750 [==============================] - 153s 204ms/step - loss: 0.1151 - accuracy: 0.9530 - val_loss: 0.0916 - val_accuracy: 0.9664
# Epoch 29/100
# 750/750 [==============================] - 153s 204ms/step - loss: 0.1157 - accuracy: 0.9523 - val_loss: 0.0934 - val_accuracy: 0.9664
# Epoch 30/100
# 750/750 [==============================] - 150s 200ms/step - loss: 0.1161 - accuracy: 0.9523 - val_loss: 0.0950 - val_accuracy: 0.9664
# Epoch 31/100
# 750/750 [==============================] - 150s 200ms/step - loss: 0.1112 - accuracy: 0.9568 - val_loss: 0.0905 - val_accuracy: 0.9684
# Epoch 32/100
# 750/750 [==============================] - 151s 201ms/step - loss: 0.1109 - accuracy: 0.9563 - val_loss: 0.0869 - val_accuracy: 0.9688
# Epoch 33/100
# 750/750 [==============================] - 152s 202ms/step - loss: 0.1092 - accuracy: 0.9571 - val_loss: 0.0946 - val_accuracy: 0.9676
# Epoch 34/100
# 750/750 [==============================] - 148s 198ms/step - loss: 0.1124 - accuracy: 0.9552 - val_loss: 0.0885 - val_accuracy: 0.9694
# Epoch 35/100
# 750/750 [==============================] - 155s 207ms/step - loss: 0.1041 - accuracy: 0.9585 - val_loss: 0.0859 - val_accuracy: 0.9690
# Epoch 36/100
# 750/750 [==============================] - 159s 212ms/step - loss: 0.1052 - accuracy: 0.9594 - val_loss: 0.0872 - val_accuracy: 0.9696
# Epoch 37/100
# 750/750 [==============================] - 164s 219ms/step - loss: 0.1023 - accuracy: 0.9599 - val_loss: 0.0855 - val_accuracy: 0.9696
# Epoch 38/100
# 750/750 [==============================] - 162s 216ms/step - loss: 0.1023 - accuracy: 0.9586 - val_loss: 0.0881 - val_accuracy: 0.9688
# Epoch 39/100
# 750/750 [==============================] - 158s 211ms/step - loss: 0.1015 - accuracy: 0.9595 - val_loss: 0.0856 - val_accuracy: 0.9704
# Epoch 40/100
# 750/750 [==============================] - 156s 208ms/step - loss: 0.1005 - accuracy: 0.9592 - val_loss: 0.0847 - val_accuracy: 0.9702
# Epoch 41/100
# 750/750 [==============================] - 156s 207ms/step - loss: 0.1009 - accuracy: 0.9599 - val_loss: 0.0868 - val_accuracy: 0.9696
# Epoch 42/100
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0989 - accuracy: 0.9599 - val_loss: 0.0836 - val_accuracy: 0.9706
# Epoch 43/100
# 750/750 [==============================] - 155s 207ms/step - loss: 0.0969 - accuracy: 0.9629 - val_loss: 0.0822 - val_accuracy: 0.9714
# Epoch 44/100
# 750/750 [==============================] - 151s 201ms/step - loss: 0.0954 - accuracy: 0.9616 - val_loss: 0.0845 - val_accuracy: 0.9700
# Epoch 45/100
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0903 - accuracy: 0.9642 - val_loss: 0.0849 - val_accuracy: 0.9700
# Epoch 46/100
# 750/750 [==============================] - 151s 202ms/step - loss: 0.0928 - accuracy: 0.9624 - val_loss: 0.0809 - val_accuracy: 0.9710
# Epoch 47/100
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0914 - accuracy: 0.9658 - val_loss: 0.0805 - val_accuracy: 0.9712
# Epoch 48/100
# 750/750 [==============================] - 151s 201ms/step - loss: 0.0901 - accuracy: 0.9648 - val_loss: 0.0810 - val_accuracy: 0.9708
# Epoch 49/100
# 750/750 [==============================] - 152s 202ms/step - loss: 0.0899 - accuracy: 0.9645 - val_loss: 0.0790 - val_accuracy: 0.9714
# Epoch 50/100
# 750/750 [==============================] - 152s 203ms/step - loss: 0.0885 - accuracy: 0.9656 - val_loss: 0.0840 - val_accuracy: 0.9700
# Epoch 51/100
# 750/750 [==============================] - 147s 196ms/step - loss: 0.0902 - accuracy: 0.9642 - val_loss: 0.0808 - val_accuracy: 0.9712
# Epoch 52/100
# 750/750 [==============================] - 145s 194ms/step - loss: 0.0840 - accuracy: 0.9681 - val_loss: 0.0812 - val_accuracy: 0.9706
# Epoch 53/100
# 750/750 [==============================] - 150s 200ms/step - loss: 0.0845 - accuracy: 0.9669 - val_loss: 0.0798 - val_accuracy: 0.9706
# Epoch 54/100
# 750/750 [==============================] - 145s 194ms/step - loss: 0.0870 - accuracy: 0.9652 - val_loss: 0.0827 - val_accuracy: 0.9712

# %%
# 학습 곡선을 나타내는 함수
def plot_loss_curve(history):
    plt.figure(figsize=(15, 10))

    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show()   
    
    print("train loss=", history.history['loss'][-1])
    print("validation loss=", history.history['val_loss'][-1])
    
def plot_acc_curve(history):
    plt.figure(figsize=(15, 10))

    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show()   
    
    print("train accuracy=", history.history['accuracy'][-1])
    print("validation accuracy=", history.history['val_accuracy'][-1])

plot_loss_curve(history)
plot_acc_curve(history)
# Out:
# train loss= 0.08697018027305603
# validation loss= 0.08272165060043335
# train accuracy= 0.9652000069618225
# validation accuracy= 0.9711999893188477

# %%
model.save('C:/Users/s_csmscox/jupyterSave/dvc/dvc_VGG16_ImgGen_FT_224')
# Out:
# WARNING:tensorflow:From C:\Users\s_csmscox\Anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\s_csmscox\Anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: C:/Users/s_csmscox/jupyterSave/dvc/dvc_VGG16_ImgGen_FT_224\assets

# %%
import pathlib
import os,glob
import numpy as np
from PIL import Image
from tensorflow.keras.utils import to_categorical

directory = 'C:/Users/s_csmscox/jupyterSave/dvc/test'
categories = ["0","1"] # dog = 1, cat = 0
nb_classes = len(categories)

w = 224
h = 224

X = []
y = []

for idx, obj in enumerate(categories):

    image_dir = directory + "/" + obj
    files = glob.glob(image_dir+"/*.jpg")
    print(obj, " 파일 길이 : ", len(files))
    
    for i, f in enumerate(files):
        img = Image.open(f)
        
        # 사이즈 조절
        img = img.resize((w, h))
        
        img = np.asarray(img)
        img = img.reshape(w,h,3)

        X.append(img)
        y.append(idx)

        if i % 10000 == 0:
            print(obj, " : ", f)
            
X_test = np.array(X)
X_test = X_test/255

y_test = np.array(y)
y_test = to_categorical(y_test)
# Out:
# 0  파일 길이 :  2500
# 0  :  C:/Users/s_csmscox/jupyterSave/dvc/test/0\cat.7500.jpg
# 1  파일 길이 :  2500
# 1  :  C:/Users/s_csmscox/jupyterSave/dvc/test/1\dog.7500.jpg

# %%
# 모델 평가
print("-- Evaluate --")
scores = model.evaluate(X_test, y_test)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))
# Out:
# -- Evaluate --
# 157/157 [==============================] - 11s 68ms/step - loss: 0.0724 - accuracy: 0.9716
# accuracy: 97.16%
